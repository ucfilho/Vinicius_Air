# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Vinicius_Air/blob/main/Stastical/Ajuste_feito_usando_krieg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !pip install GPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import GPy
GPy.plotting.change_plotting_library('plotly')
# Out:
#  /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_deprecations.py:385: DeprecationWarning:plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
 # generate an independent variable 
X = np.linspace(-10, 30, 100)
# generate a normally distributed residual
e = np.random.normal(10, 5, 100)
# generate ground truth
y = 10 + 4*X + e
df = pd.DataFrame({'x':X, 'y':y})
df.head()
# Out:
#            x          y
# 0 -10.000000 -25.499341
# 1  -9.595960  -5.782312
# 2  -9.191919 -18.459159
# 3  -8.787879  -5.030856
# 4  -8.383838 -12.635075

# %%
m = GPy.models.GPRegression(X, y)

m.kern.lengthscale = 10.0

if optimize:
  m.optimize("bfgs", max_iters=200)
if MPL_AVAILABLE and plot:
  m.plot(plot_limits=(1850, 2050))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0f9ddb387998> in <module>()
# ----> 1 m = GPy.models.GPRegression(X, y)
#       2
#       3 m.kern.lengthscale = 10.0
#       4
#       5 if optimize:
#
# /usr/local/lib/python3.7/dist-packages/paramz/parameterized.py in __call__(self, *args, **kw)
#      51         #import ipdb;ipdb.set_trace()
#      52         initialize = kw.pop('initialize', True)
# ---> 53         self = super(ParametersChangedMeta, self).__call__(*args, **kw)
#      54         #logger.debug("finished init")
#      55         self._in_init_ = False
#
# /usr/local/lib/python3.7/dist-packages/GPy/models/gp_regression.py in __init__(self, X, Y, kernel, Y_metadata, normalizer, noise_var, mean_function)
#      30
#      31         if kernel is None:
# ---> 32             kernel = kern.RBF(X.shape[1])
#      33
# ...

# %%
X.shape,y.shape
# Out:
# ((100,), (100,))

# %%
#type GPy.kern.<tab> here:
GPy.kern.BasisFuncKernel
# Out:
# GPy.kern.src.basis_funcs.BasisFuncKernel

# %%
m = GPy.models.GPRegression(X,y,kernel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-229a11763a1f> in <module>()
# ----> 1 m = GPy.models.GPRegression(X,y,kernel)
#
# NameError: name 'kernel' is not defined

# %%
from IPython.display import display
display(m)
